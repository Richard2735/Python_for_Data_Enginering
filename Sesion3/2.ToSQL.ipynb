# %%
import pandas as pd

# %%
path = '../Sesion2/data_retail'

path_customers = f'{path}/customers'
path_orders = f'{path}/orders'
path_order_items = f'{path}/order_items'
path_products = f'{path}/products'
path_categories = f'{path}/categories'
path_departments = f'{path}/departments'

# %%
df_customers = pd.read_csv(path_customers, sep='|', header = None)
df_orders = pd.read_csv(path_orders,sep='|',header = None)
df_order_items = pd.read_csv(path_order_items,sep='|',header = None)
df_products = pd.read_csv(path_products,sep='|',header = None)
df_categories = pd.read_csv(path_categories,sep='|',header = None,names=['category_id','category_department_id','category_name'])
df_departments = pd.read_csv(path_departments,sep='|',header = None, names=['deparment_id','department_name'])

# %%
df_categories.head()
# Out:
#    category_id  category_department_id        category_name
# 0            1                       2             Football
# 1            2                       2               Soccer
# 2            3                       2  Baseball & Softball
# 3            4                       2           Basketball
# 4            5                       2             Lacrosse

# %%
df_departments
# Out:
#    deparment_id department_name
# 0             2         Fitness
# 1             3        Footwear
# 2             4         Apparel
# 3             5            Golf
# 4             6        Outdoors
# 5             7        Fan Shop

# %%
df_departments['department_name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: department_name, dtype: bool

# %%
df_departments['department_name'].duplicated().any()
# Out:
# np.False_

# %%
if df_departments['department_name'].duplicated().any():
    print("Hay departamentos duplicados en el dataframe")
    exit(1)
else:
    print("No existe duplicados")
# Out:
# No existe duplicados

# %%
def validate_department(df):
    if df_departments['department_name'].duplicated().any():
        print("Hay departamentos duplicados en el dataframe")
        exit(1)
    else:
        print("No existe duplicados")

# %%
validate_department(df_categories)
# Out:
# No existe duplicados

# %%
def validate_duplicated(df, column_name):
    if df[column_name].duplicated().any():
        print(f"Hay departamentos duplicados en el dataframe {column_name}")
        exit(1)
    else:
        print("No existe duplicados")

# %%
validate_duplicated(df_departments, 'department_name')
# Out:
# No existe duplicados

# %%
validate_duplicated(df_categories, 'category_department_id')
# Out:
# Hay departamentos duplicados en el dataframe category_department_id

# %%
valid_ids = set(df_departments['deparment_id'])
valid_ids
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
def validate_ids(df, valid_ids):
    if not df_categories['category_department_id'].isin(valid_ids).all():
        print("Hay ids que no se encuentran en el dataframe")

    else:
        print("OK")

# %%
if not df_categories['category_department_id'].isin(valid_ids).all():
        print("Hay ids que no se encuentran en el dataframe")
# Out:
# Hay ids que no se encuentran en el dataframe

# %%
validate_ids(df_categories, valid_ids)
# Out:
# Hay ids que no se encuentran en el dataframe

# %%
#Realizando merge
df_departments
# Out:
#    deparment_id department_name
# 0             2         Fitness
# 1             3        Footwear
# 2             4         Apparel
# 3             5            Golf
# 4             6        Outdoors
# 5             7        Fan Shop

# %%
df_categories.head()
# Out:
#    category_id  category_department_id        category_name
# 0            1                       2             Football
# 1            2                       2               Soccer
# 2            3                       2  Baseball & Softball
# 3            4                       2           Basketball
# 4            5                       2             Lacrosse

# %%
#df_departments.merge(df_categories, df_departments.department_id = df_categories.category_department_id, )

# %%
df_departments.merge(df_categories, left_on='deparment_id', right_on='category_department_id', how='left')
# Out:
#     deparment_id department_name  category_id  category_department_id  \
# 0              2         Fitness            1                       2
# 1              2         Fitness            2                       2
# 2              2         Fitness            3                       2
# 3              2         Fitness            4                       2
# 4              2         Fitness            5                       2
# 5              2         Fitness            6                       2
# 6              2         Fitness            7                       2
# 7              2         Fitness            8                       2
# 8              3        Footwear            9                       3
# 9              3        Footwear           10                       3
# 10             3        Footwear           11                       3
# 11             3        Footwear           12                       3
# ...

# %%
df_departments.to_csv('deparments.csv', index=False)

# %%
df_departments.to_json('deparments.json', orient='records', indent=2)

# %%
import sqlalchemy as db
import pandas as pd

# %%
engine = db.create_engine('mysql+mysqlconnector://root:root@127.0.0.1:3310/retail_db?charset=utf8mb4')
conn = engine.connect()

# %%
df_departments.to_sql('deparments_2', con=conn, index=False)
# Out:
# 6

# %%
pd.read_sql_table('deparments_2', con=conn)
# Out:
#    deparment_id department_name
# 0             2         Fitness
# 1             3        Footwear
# 2             4         Apparel
# 3             5            Golf
# 4             6        Outdoors
# 5             7        Fan Shop

# %%
import sqlalchemy as db
import pandas as pd

engine = db.create_engine('mysql+mysqlconnector://root:root@127.0.0.1:3310/retail_db?charset=utf8mb4')
conn = engine.connect()

# %%
df_customers = pd.read_sql_table('customers', con=conn)
df_orders = pd.read_sql_table('orders', con=conn)
df_order_items = pd.read_sql_table('order_items', con=conn)
df_products = pd.read_sql_table('products', con=conn)
df_categories = pd.read_sql_table('categories', con=conn)
df_departments = pd.read_sql_table('departments', con=conn)

# %%
print(f" Total de clientes unicos: {df_customers['customer_id'].nunique()}")
# Out:
#  Total de clientes unicos: 12435

# %%
#Cantidad de clientes por estado
df_customers['customer_state'].value_counts()
# Out:
# customer_state
# PR    4771
# CA    2012
# NY     775
# TX     635
# IL     523
# FL     374
# OH     276
# PA     261
# MI     254
# NJ     219
# AZ     213
# GA     169
# MD     164
# NC     150
# VA     136
# CO     122
# OR     119
# MA     113
# TN     104
# NV     103
# MO      92
# HI      87
# CT      73
# NM      73
# WA      72
# UT      69
# WI      64
# LA      63
# DC      42
# SC      41
# IN      40
# MN      39
# KY      35
# KS      29
# DE      23
# OK      19
# WV      16
# RI      15
# ND      14
# AR      12
# ID       9
# MT       7
# IA       5
# AL       3
# Name: count, dtype: int64

# %%
#cuales son los productos mas caros y mas baratos
df_products.head()
# Out:
#    product_id  product_category_id  \
# 0           1                    2
# 1           2                    2
# 2           3                    2
# 3           4                    2
# 4           5                    2
#
#                                     product_name product_description  \
# 0  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U
# 1  Under Armour Men's Highlight MC Football Clea
# 2  Under Armour Men's Renegade D Mid Football Cl
# 3  Under Armour Men's Renegade D Mid Football Cl
# 4  Riddell Youth Revolution Speed Custom Footbal
#
#    product_price                                      product_image
# 0          59.98  http://images.acmesports.sports/Quest+Q64+10+F...
# 1         129.99  http://images.acmesports.sports/Under+Armour+M...
# 2          89.99  http://images.acmesports.sports/Under+Armour+M...
# 3          89.99  http://images.acmesports.sports/Under+Armour+M...
# 4         199.99  http://images.acmesports.sports/Riddell+Youth+...

# %%
df_products.loc[df_products['product_price'].idxmax()]
# Out:
# product_id                                                           208
# product_category_id                                                   10
# product_name                                         SOLE E35 Elliptical
# product_description
# product_price                                                    1999.99
# product_image          http://images.acmesports.sports/SOLE+E35+Ellip...
# Name: 207, dtype: object

# %%
df_products.loc[df_products['product_price'].idxmin()]
# Out:
# product_id                                                            38
# product_category_id                                                    3
# product_name               Nike Men's Hypervenom Phantom Premium FG Socc
# product_description
# product_price                                                        0.0
# product_image          http://images.acmesports.sports/Nike+Men%27s+H...
# Name: 37, dtype: object

# %%
#cuales son los productos mas comprados por cada cliente
#cual es el total de gatado por cliente
#categorias mas populares que se ha vendido
#promedio por dia, mes, año

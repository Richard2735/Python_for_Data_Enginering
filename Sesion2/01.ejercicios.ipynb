# %%
import random

# %%
lista = [random.randint(0,100) for i in range(1,100)]
print(lista)
# Out:
# [56, 72, 37, 48, 90, 10, 91, 19, 48, 80, 5, 100, 3, 61, 43, 48, 87, 91, 39, 22, 88, 16, 11, 61, 96, 77, 7, 7, 49, 8, 76, 73, 88, 68, 1, 21, 26, 25, 74, 2, 70, 67, 85, 53, 95, 34, 11, 94, 89, 43, 87, 37, 25, 32, 64, 8, 15, 3, 4, 44, 27, 2, 46, 96, 39, 96, 8, 28, 21, 49, 81, 43, 62, 98, 27, 77, 12, 79, 46, 15, 71, 99, 67, 17, 29, 78, 95, 25, 13, 57, 58, 86, 18, 50, 4, 46, 28, 13, 96]

# %%
# funcion para sumar numeros pares
def suma_pares(lista):
    sum = 0
    for item in lista:
        if item % 2 == 0:
            sum = sum + item

    return sum

print(suma_pares(lista))
# Out:
# 2850

# %%
# funcion para buscar un elemento en una lista
def buscar_elemento(lista, elemento):
    for item in lista:
        if item == elemento:
            return True
    return False

print(buscar_elemento(lista, 77))
# Out:
# True

# %%
# Crear una función que reciba una lista de palabras y retorne un diccionario con 
# la cantidad de veces que aparece cada palabra.
def contar_palabras(lista):
    dict_frec = {}
    for palabra in lista:
        if palabra in dict_frec:
            dict_frec[palabra] = dict_frec[palabra] + 1
        else:
            dict_frec[palabra] = 1
    
    return dict_frec

palabras = ["python", "java", "python", "c++", "python", "java"]
resultado = contar_palabras(palabras)
print(resultado)
# Out:
# {'python': 3, 'java': 2, 'c++': 1}

# %%
# Crear una función que reciba un diccionario donde las llaves sean nombres y los valores sean notas.
# Debe retornar el nombre del alumno con la nota más alta
def mejor_alumno(diccionario):
    nombre = ''
    nota_aux = -1

    for nombre_dict, nota in diccionario.items():
        if nota > nota_aux:
            nota_aux = nota
            nombre = nombre_dict
    return nombre

notas = {"Ana": 15, "Luis": 18, "María": 17, "Pedro": 19}
print(mejor_alumno(notas))
# Out:
# Pedro

# %%
! python -m pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.15.3)
# WARNING: pymongo 4.15.3 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pymongo[srv]) (2.8.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
! pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.15.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pymongo) (2.8.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://richardad69_db_user:sQ7C1NjOgK3F11u7@cluster0.bzfigjj.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db_mflix = client['sample_mflix']

# %%
collection_users = db_mflix['users']

users = collection_users.find({})

df_users = pd.DataFrame(users)

df_users
# Out:
#                           _id                name  \
# 0    59b99db4cfa9a34dcd7885b6           Ned Stark
# 1    59b99db6cfa9a34dcd7885ba    Cersei Lannister
# 2    59b99db6cfa9a34dcd7885bb  Daenerys Targaryen
# 3    59b99db8cfa9a34dcd7885be   Viserys Targaryen
# 4    59b99dbecfa9a34dcd7885ca       Samwell Tarly
# ..                        ...                 ...
# 180  59b99e09cfa9a34dcd78866c         Ashlee Hart
# 181  5db1c37e4a68c31f10cf0a9f                 foo
# 182  59b99e06cfa9a34dcd788665       Connie Barton
# 183  59b99e08cfa9a34dcd78866a     Shawn Mccormick
# 184  59b99e06cfa9a34dcd788666      Patrick Knight
#
#                                 email  \
# 0            sean_bean@gameofthron.es
# 1          lena_headey@gameofthron.es
# 2        emilia_clarke@gameofthron.es
# 3          harry_lloyd@gameofthron.es
# 4    john_bradley-west@gameofthron.es
# ..                                ...
# 180         ashlee_hart@fakegmail.com
# 181                    foobaz@bar.com
# 182       connie_barton@fakegmail.com
# 183     shawn_mccormick@fakegmail.com
# 184      patrick_knight@fakegmail.com
#
#                                               password preferences
# 0    $2b$12$UREFwsRUoyF0CRqGNK0LzO0HM/jLhgUCNNIJ9RJ...         NaN
# 1    $2b$12$FExjgr7CLhNCa.oUsB9seub8mqcHzkJCFZ8heMc...         NaN
# 2    $2b$12$NzpbWHdMytemLtTfFKduHenr2NZ.rvxIKuYM4AW...         NaN
# 3    $2b$12$cpwVmU4DyuQxgwpdrVJhaudzbKOXlHRbf.tpCuH...         NaN
# 4    $2b$12$ZcZj9wKjlT/dCCrmupiZZ..JA3c9HoufxRygL1D...         NaN
# ..                                                 ...         ...
# 180  $2b$12$S707opDk6HG/Lqk7MaHeQ.1N36I6kEUOhRv/RQE...         NaN
# 181                                             foobar          {}
# 182  $2b$12$dFHzE0VmGHX7K7Je4QWZ0ucv4XX7zup9FWvrF8N...         NaN
# 183  $2b$12$fVJEFj7SXlqT0EmE9k00FuZLNH52NFSPriUqm8G...         NaN
# 184  $2b$12$GrKhwH1qeeJNGcGLmjg9f.k7ruCRxGUbfm4z3mg...         NaN
#
# [185 rows x 5 columns]
